# %%
[10:24 pm, 18/11/2025] Rupinder Kaur Class Teacher 11J: import pandas as pd

file_name = input("CSV file name: ")
df = pd.read_csv(file_name)

# Drop rows with any missing values
df_cleaned = df.dropna()

df_filled = df.fillna("MISSING")

print("Rows after dropna:")
print(df_cleaned)

print("\nData after fillna:")
print(df_filled)
[10:30 pm, 18/11/2025] Rupinder Kaur Class Teacher 11J: if {'temp_min', 'temp_max'}.issubset(df.columns):
    df['temp_avg'] = (df['temp_min'] + df['temp_max']) / 2

precipitation_cols = [c for c in df.columns if  'precipitation' in c.lower()]
if precipitation_cols:
    df['total_precipitation'] = df[precipitation_cols].sum(axis=1)

if {'wind_min', 'wind_max'}.issubset(df.columns):
    df['wind_avg'] = (df['wind_min'] + df['wind_max']) / 2

print(df.head())
